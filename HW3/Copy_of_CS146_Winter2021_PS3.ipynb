# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import TensorDataset, DataLoader
from PIL import Image

# %%
# To add your own Drive Run this cell.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
######################################################################
# OneLayerNetwork
######################################################################

class OneLayerNetwork(torch.nn.Module):
    def __init__(self):
        super(OneLayerNetwork, self).__init__()

        ### ========== TODO : START ========== ###
        ### part d: implement OneLayerNetwork with torch.nn.Linear
        self.linearlayer = torch.nn.Linear(784, 3)

        ### ========== TODO : END ========== ###

    def forward(self, x):
        # x.shape = (n_batch, n_features)

        ### ========== TODO : START ========== ###
        ### part d: implement the foward function
        outputs = self.linearlayer(x)
        ### ========== TODO : END ========== ###
        return outputs

# %%
######################################################################
# TwoLayerNetwork
######################################################################

class TwoLayerNetwork(torch.nn.Module):
    def __init__(self):
        super(TwoLayerNetwork, self).__init__()
        ### ========== TODO : START ========== ###
        ### part g: implement TwoLayerNetwork with torch.nn.Linear
        self.linearlayerOne = torch.nn.Linear(784, 400)
        self.linearlayerTwo = torch.nn.Linear(400,3)
        ### ========== TODO : END ========== ###

    def forward(self, x):
        # x.shape = (n_batch, n_features)

        ### ========== TODO : START ========== ###
        ### part g: implement the foward function
        outputs = self.linearlayerTwo(self.linearlayerOne(x))
        ### ========== TODO : END ========== ###
        return outputs

# %%
# load data from csv
# X.shape = (n_examples, n_features), y.shape = (n_examples, )
def load_data(filename):
    data = np.loadtxt(filename)
    y = data[:, 0].astype(int)
    X = data[:, 1:].astype(np.float32) / 255
    return X, y

# %%
# plot one example
# x.shape = (features, )
def plot_img(x):
    x = x.reshape(28, 28)
    img = Image.fromarray(x*255)
    plt.figure()
    plt.imshow(img)
    return

# %%
def evaluate_loss(model, criterion, dataloader):
    model.eval()
    total_loss = 0.0
    for batch_X, batch_y in dataloader:
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        total_loss += loss.item()
        
    return total_loss / len(dataloader)

# %%
def evaluate_acc(model, dataloader):
    model.eval()
    total_acc = 0.0
    for batch_X, batch_y in dataloader:
        outputs = model(batch_X)
        predictions = torch.argmax(outputs, dim=1)
        total_acc += (predictions==batch_y).sum()
        
    return total_acc / len(dataloader.dataset)

# %%
def train(model, criterion, optimizer, train_loader, valid_loader):
    train_loss_list = []
    valid_loss_list = []
    train_acc_list = []
    valid_acc_list = []
    for epoch in range(1, 31):
        model.train()
        for batch_X, batch_y in train_loader:
            ### ========== TODO : START ========== ###
            ### part f: implement the training process
            pred = model.forward(batch_X)
            optimizer.zero_grad()
            loss = criterion(pred, batch_y)
            loss.backward()
            optimizer.step()
            ### ========== TODO : END ========== ###
            
        train_loss = evaluate_loss(model, criterion, train_loader)
        valid_loss = evaluate_loss(model, criterion, valid_loader)
        train_acc = evaluate_acc(model, train_loader)
        valid_acc = evaluate_acc(model, valid_loader)
        train_loss_list.append(train_loss)
        valid_loss_list.append(valid_loss)
        train_acc_list.append(train_acc)
        valid_acc_list.append(valid_acc)

        print(f"| epoch {epoch:2d} | train loss {train_loss:.6f} | train acc {train_acc:.6f} | valid loss {valid_loss:.6f} | valid acc {valid_acc:.6f} |")

    return train_loss_list, valid_loss_list, train_acc_list, valid_acc_list

# %%
######################################################################
# main
######################################################################

def main():

    # fix random seed
    np.random.seed(0)
    torch.manual_seed(0)

    # load data with correct file path

    ### ========== TODO : START ========== ###
    data_directory_path =  "/content/drive/My Drive/CS M146 Data"
    ### ========== TODO : END ========== ###

    # X.shape = (n_examples, n_features)
    # y.shape = (n_examples, )
    X_train, y_train = load_data(os.path.join(data_directory_path, "ps3_train.csv"))
    X_valid, y_valid = load_data(os.path.join(data_directory_path, "ps3_valid.csv"))
    X_test, y_test = load_data(os.path.join(data_directory_path, "ps3_test.csv"))

    ### ========== TODO : START ========== ###
    ### part a: print out three training images with different labels
    plot_img(X_train[5])
    plot_img(X_train[6])
    plot_img(X_train[7])
    
    ### ========== TODO : END ========== ###

    print("Data preparation...")

    ### ========== TODO : START ========== ###
    ### part b: convert numpy arrays to tensors
    X_train = torch.from_numpy(X_train)
    X_valid = torch.from_numpy(X_valid)
    X_test = torch.from_numpy(X_test)
    y_train = torch.from_numpy(y_train).type(torch.LongTensor)
    y_valid = torch.from_numpy(y_valid).type(torch.LongTensor)
    y_test = torch.from_numpy(y_test).type(torch.LongTensor)
    ### ========== TODO : END ========== ###

    ### ========== TODO : START ========== ###
    ### part c: prepare dataloaders for training, validation, and testing
    ###         we expect to get a batch of pairs (x_n, y_n) from the dataloader
    train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=10)
    valid_loader = DataLoader(TensorDataset(X_valid, y_valid), batch_size=10)
    test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=10)
    ### ========== TODO : END ========== ###

    ### ========== TODO : START ========== ###
    ### part e: prepare OneLayerNetwork, criterion, and optimizer
    model_one = OneLayerNetwork()
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model_one.parameters(), lr=0.0005)
    ### ========== TODO : END ========== ###

    print("Start training OneLayerNetwork...")
    results_one = train(model_one, criterion, optimizer, train_loader, valid_loader)
    print("Done!")

    ### ========== TODO : START ========== ###
    ### part h: prepare TwoLayerNetwork, criterion, and optimizer
    model_two = TwoLayerNetwork()
    criterion = torch.nn.CrossEntropyLoss()
    optimizer =  torch.optim.SGD(model_two.parameters(), lr=0.0005)
    ### ========== TODO : END ========== ###

    print("Start training TwoLayerNetwork...")
    results_two = train(model_two, criterion, optimizer, train_loader, valid_loader)
    print("Done!")

    one_train_loss, one_valid_loss, one_train_acc, one_valid_acc = results_one
    two_train_loss, two_valid_loss, two_train_acc, two_valid_acc = results_two

    ### ========== TODO : START ========== ###
    ### part i: generate a plot to comare one_train_loss, one_valid_loss, two_train_loss, two_valid_loss
    epoch = np.arange(1,31)
    plt.figure()
    plt.plot(epoch, one_train_loss)
    plt.plot(epoch, one_valid_loss)
    plt.plot(epoch , two_train_loss)
    plt.plot(epoch , two_valid_loss)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Epoch vs Loss Plot')
    plt.legend(['one_train_loss', 'one_valid_loss', 'two_train_loss', 'two_valid_loss']) 
    plt.show()
    ### ========== TODO : END ========== ###

    ### ========== TODO : START ========== ###
    ### part j: generate a plot to comare one_train_acc, one_valid_acc, two_train_acc, two_valid_acc
    plt.figure()
    plt.plot(epoch, one_train_acc)
    plt.plot(epoch, one_valid_acc)
    plt.plot(epoch , two_train_acc)
    plt.plot(epoch , two_valid_acc)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Epoch vs Accuracy Plot')
    plt.legend(['one_train_acc', 'one_valid_acc', 'two_train_acc', 'two_valid_acc']) 
    plt.show()
    ### ========== TODO : END ========== ##

    ### ========== TODO : START ========== ###
    ### part k: calculate the test accuracy
    test_accOne = evaluate_acc(model_one, test_loader)
    test_accTwo = evaluate_acc(model_two, test_loader)
    print("One layer accuracy: ", test_accOne)
    print("Two layer accuracy: ", test_accTwo)

    ### ========== TODO : END ========== ###

    ### ========== TODO : START ========== ###
    ### part l: replace the SGD optimizer with the Adam optimizer and do the experiments again
    model_one = OneLayerNetwork()
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_one.parameters(), lr=0.0005)
    print("Start training OneLayerNetwork...")
    results_one = train(model_one, criterion, optimizer, train_loader, valid_loader)
    print("Done!")

    model_two = TwoLayerNetwork()
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model_two.parameters(), lr=0.0005)
    print("Start training TwoLayerNetwork...")
    results_two = train(model_two, criterion, optimizer, train_loader, valid_loader)
    print("Done!")

    one_train_loss, one_valid_loss, one_train_acc, one_valid_acc = results_one
    two_train_loss, two_valid_loss, two_train_acc, two_valid_acc = results_two

    epoch = np.arange(1,31)
    plt.figure()
    plt.plot(epoch, one_train_loss)
    plt.plot(epoch, one_valid_loss)
    plt.plot(epoch , two_train_loss)
    plt.plot(epoch , two_valid_loss)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Epoch vs Loss Plot W/ Adam Optimizer')
    plt.legend(['one_train_loss', 'one_valid_loss', 'two_train_loss', 'two_valid_loss']) 
    plt.show()

    plt.figure()
    plt.plot(epoch, one_train_acc)
    plt.plot(epoch, one_valid_acc)
    plt.plot(epoch , two_train_acc)
    plt.plot(epoch , two_valid_acc)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Epoch vs Accuracy Plot W/ Adam Optimizer')
    plt.legend(['one_train_acc', 'one_valid_acc', 'two_train_acc', 'two_valid_acc']) 
    plt.show()

    test_accOne = evaluate_acc(model_one, test_loader)
    test_accTwo = evaluate_acc(model_two, test_loader)
    print("One layer accuracy: ", test_accOne)
    print("Two layer accuracy: ", test_accTwo)
    ### ========== TODO : END ========== ###



if __name__ == "__main__":
    main()
# Out:
# Data preparation...
# Start training OneLayerNetwork...
# | epoch  1 | train loss 1.075398 | train acc 0.453333 | valid loss 1.084938 | valid acc 0.453333 |
# | epoch  2 | train loss 1.021364 | train acc 0.566667 | valid loss 1.031102 | valid acc 0.553333 |
# | epoch  3 | train loss 0.972648 | train acc 0.630000 | valid loss 0.982742 | valid acc 0.593333 |
# | epoch  4 | train loss 0.928398 | train acc 0.710000 | valid loss 0.938953 | valid acc 0.640000 |
# | epoch  5 | train loss 0.887963 | train acc 0.783333 | valid loss 0.899045 | valid acc 0.700000 |
# | epoch  6 | train loss 0.850839 | train acc 0.826667 | valid loss 0.862485 | valid acc 0.753333 |
# | epoch  7 | train loss 0.816627 | train acc 0.850000 | valid loss 0.828852 | valid acc 0.793333 |
# | epoch  3 | train loss 0.029937 | train acc 1.000000 | valid loss 0.084753 | valid acc 0.973333 |
# | epoch  4 | train loss 0.018923 | train acc 1.000000 | valid loss 0.078430 | valid acc 0.980000 |
# | epoch  5 | train loss 0.012309 | train acc 1.000000 | valid loss 0.070907 | valid acc 0.980000 |
# | epoch  6 | train loss 0.008918 | train acc 1.000000 | valid loss 0.067597 | valid acc 0.980000 |
# | epoch  7 | train loss 0.006734 | train acc 1.000000 | valid loss 0.065326 | valid acc 0.980000 |
# | epoch  8 | train loss 0.005272 | train acc 1.000000 | valid loss 0.063662 | valid acc 0.980000 |
# | epoch  9 | train loss 0.004243 | train acc 1.000000 | valid loss 0.062423 | valid acc 0.980000 |
# | epoch 10 | train loss 0.003491 | train acc 1.000000 | valid loss 0.061474 | valid acc 0.980000 |
# | epoch 11 | train loss 0.002924 | train acc 1.000000 | valid loss 0.060718 | valid acc 0.980000 |
# | epoch 12 | train loss 0.002486 | train acc 1.000000 | valid loss 0.060106 | valid acc 0.980000 |
# | epoch 13 | train loss 0.002141 | train acc 1.000000 | valid loss 0.059600 | valid acc 0.980000 |
# | epoch 14 | train loss 0.001864 | train acc 1.000000 | valid loss 0.059176 | valid acc 0.980000 |
# | epoch 15 | train loss 0.001638 | train acc 1.000000 | valid loss 0.058816 | valid acc 0.980000 |
# | epoch 16 | train loss 0.001450 | train acc 1.000000 | valid loss 0.058508 | valid acc 0.980000 |
# | epoch 17 | train loss 0.001294 | train acc 1.000000 | valid loss 0.058240 | valid acc 0.980000 |
# | epoch 18 | train loss 0.001161 | train acc 1.000000 | valid loss 0.058007 | valid acc 0.980000 |
# | epoch 19 | train loss 0.001048 | train acc 1.000000 | valid loss 0.057801 | valid acc 0.980000 |
# | epoch 20 | train loss 0.000951 | train acc 1.000000 | valid loss 0.057620 | valid acc 0.980000 |
# | epoch 21 | train loss 0.000867 | train acc 1.000000 | valid loss 0.057459 | valid acc 0.980000 |
# | epoch 22 | train loss 0.000793 | train acc 1.000000 | valid loss 0.057315 | valid acc 0.980000 |
# | epoch 23 | train loss 0.000729 | train acc 1.000000 | valid loss 0.057186 | valid acc 0.980000 |
# | epoch 24 | train loss 0.000671 | train acc 1.000000 | valid loss 0.057070 | valid acc 0.980000 |
# | epoch 25 | train loss 0.000621 | train acc 1.000000 | valid loss 0.056966 | valid acc 0.980000 |
# | epoch 26 | train loss 0.000576 | train acc 1.000000 | valid loss 0.056871 | valid acc 0.980000 |
# | epoch 27 | train loss 0.000535 | train acc 1.000000 | valid loss 0.056785 | valid acc 0.980000 |
# | epoch 28 | train loss 0.000499 | train acc 1.000000 | valid loss 0.056707 | valid acc 0.980000 |
# | epoch 29 | train loss 0.000466 | train acc 1.000000 | valid loss 0.056636 | valid acc 0.980000 |
# | epoch 30 | train loss 0.000436 | train acc 1.000000 | valid loss 0.056571 | valid acc 0.980000 |
# Done!
# One layer accuracy:  tensor(0.9733)
# Two layer accuracy:  tensor(0.9733)
